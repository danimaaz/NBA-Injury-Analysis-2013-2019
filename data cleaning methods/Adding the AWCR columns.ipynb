# %%
from nba_api.stats.static import players
from nba_api.stats.static import teams 
from nba_api.stats.endpoints import boxscoreplayertrackv2
from nba_api.stats.endpoints import leaguegamelog
from nba_api.stats.endpoints import leaguegamefinder
import pandas as pd
from nba_api.stats.static import teams
from nba_api.stats.endpoints import leaguegamefinder
from datetime import datetime,timedelta
import time
import os
import requests

df = pd.read_csv(r"C:\Users\Dani\Downloads\Final_2013_Version_with_counts.csv")

#function that gets the distance a player travelled over the past 7 days (in game only)
#and determines the average distance the player travelled per day over that timeframe
#the reasoning behind this is explained in the methodology section of the project

def get_avg_7_days(row):
    player_id = row['player_id']
    team_id = row['Team_id']
    days_since_start_of_playoffs = row['days_since_start_of_playoffs']
    date_7_day_back = row['7_day_back']
    days_since_start = row['days since start']
    szn_type = row['Season Type']
    szn = row['Season']
    playoff_start_date = row['playoff start date']
    current_date = row['Date_adjusted']
    if szn_type == 'Playoffs':
        if days_since_start_of_playoffs<7:
            team_since_playoffs = leaguegamefinder.LeagueGameFinder(season_nullable=szn,date_from_nullable = playoff_start_date,date_to_nullable = current_date, team_id_nullable=team_id, league_id_nullable='00', season_type_nullable=szn_type).get_data_frames()[0]['GAME_ID']
            team_before_playoffs = leaguegamefinder.LeagueGameFinder(season_nullable=szn,date_from_nullable = date_7_day_back,date_to_nullable = playoff_start_date, team_id_nullable=team_id, league_id_nullable='00', season_type_nullable='Regular Season').get_data_frames()[0]['GAME_ID']
            dist_past_7_days = []
            for l in team_since_playoffs:
                p7dT = boxscoreplayertrackv2.BoxScorePlayerTrackV2(l).get_data_frames()[0]
                if len(p7dT[p7dT['PLAYER_ID']==player_id].index.tolist())>0:
                    p7d_player = (p7dT.loc[p7dT['PLAYER_ID']==player_id]).iloc[0]['DIST']
                else:
                    p7d_player=0
                dist_past_7_days.append(p7d_player)
                time.sleep(0.6)
            for l in team_before_playoffs:
                p7dT = boxscoreplayertrackv2.BoxScorePlayerTrackV2(l).get_data_frames()[0]
                if len(p7dT[p7dT['PLAYER_ID']==player_id].index.tolist())>0:
                    p7d_player = (p7dT.loc[p7dT['PLAYER_ID']==player_id]).iloc[0]['DIST']
                else:
                    p7d_player=0
                dist_past_7_days.append(p7d_player)
                time.sleep(0.6)
            seven_day_average = sum(dist_past_7_days)/7
            return seven_day_average
        else:
            team_past_7_days = leaguegamefinder.LeagueGameFinder(season_nullable=szn,date_from_nullable = date_7_day_back,date_to_nullable = current_date, team_id_nullable=team_id, league_id_nullable='00', season_type_nullable=szn_type).get_data_frames()[0]['GAME_ID']
            dist_past_7_days = []
            for l in team_past_7_days:
                p7dT = boxscoreplayertrackv2.BoxScorePlayerTrackV2(l).get_data_frames()[0]
                if len(p7dT[p7dT['PLAYER_ID']==player_id].index.tolist())>0:
                    p7d_player = (p7dT.loc[p7dT['PLAYER_ID']==player_id]).iloc[0]['DIST']
                else:
                    p7d_player=0
                dist_past_7_days.append(p7d_player)
                time.sleep(0.6)
            seven_day_average = sum(dist_past_7_days)/7
            return seven_day_average
    else:
        team_past_7_days = leaguegamefinder.LeagueGameFinder(season_nullable=szn,date_from_nullable = date_7_day_back,date_to_nullable = current_date, team_id_nullable=team_id, league_id_nullable='00', season_type_nullable=szn_type).get_data_frames()[0]['GAME_ID']
        dist_over_past_7_days = []
        for l in team_past_7_days:
            p7dT = boxscoreplayertrackv2.BoxScorePlayerTrackV2(l).get_data_frames()[0]
            if len(p7dT[p7dT['PLAYER_ID']==player_id].index.tolist())>0:
                p7d_player = (p7dT.loc[p7dT['PLAYER_ID']==player_id]).iloc[0]['DIST']
            else:
                p7d_player=0
            dist_over_past_7_days.append(p7d_player)
            time.sleep(0.6)
        seven_day_average = sum(dist_over_past_7_days)/7
        return seven_day_average
print('done 1')

#function that gets the distance a player travelled over the past 28 days (in game only)
#and determines the average distance the player travelled per day over that timeframe

def get_avg_28_days(row):
    player_id = row['player_id']
    team_id = row['Team_id']
    days_since_start_of_playoffs = row['days_since_start_of_playoffs']
    date_28_day_back = row['28_day_back']
    days_since_start = row['days since start']
    szn_type = row['Season Type']
    szn = row['Season']
    playoff_start_date = row['playoff start date']
    current_date = row['Date_adjusted']
    if szn_type == 'Playoffs':
        if days_since_start_of_playoffs<28:
            team_since_playoffs = leaguegamefinder.LeagueGameFinder(season_nullable=szn,date_from_nullable = playoff_start_date,date_to_nullable = current_date, team_id_nullable=team_id, league_id_nullable='00', season_type_nullable=szn_type).get_data_frames()[0]['GAME_ID']
            team_before_playoffs = leaguegamefinder.LeagueGameFinder(season_nullable=szn,date_from_nullable = date_28_day_back,date_to_nullable = playoff_start_date, team_id_nullable=team_id, league_id_nullable='00', season_type_nullable='Regular Season').get_data_frames()[0]['GAME_ID']
            dist_past_28_days = []
            for l in team_since_playoffs:
                p28dT = boxscoreplayertrackv2.BoxScorePlayerTrackV2(l).get_data_frames()[0]
                if len(p28dT[p28dT['PLAYER_ID']==player_id].index.tolist())>0:
                    p28d_player = (p28dT.loc[p28dT['PLAYER_ID']==player_id]).iloc[0]['DIST']
                else:
                    p28d_player=0
                dist_past_28_days.append(p28d_player)
                time.sleep(0.6)
            for l in team_before_playoffs:
                p28dT = boxscoreplayertrackv2.BoxScorePlayerTrackV2(l).get_data_frames()[0]
                if len(p28dT[p28dT['PLAYER_ID']==player_id].index.tolist())>0:
                    p28d_player = (p28dT.loc[p28dT['PLAYER_ID']==player_id]).iloc[0]['DIST']
                else:
                    p28d_player=0
                dist_past_28_days.append(p28d_player)
                time.sleep(0.6)
            twentyeight_day_average = sum(dist_past_28_days)/28
            return twentyeight_day_average
        else:
            team_since_playoffs = leaguegamefinder.LeagueGameFinder(season_nullable=szn,date_from_nullable = date_28_day_back,date_to_nullable = current_date, team_id_nullable=team_id, league_id_nullable='00', season_type_nullable=szn_type).get_data_frames()[0]['GAME_ID']
            dist_past_28_days = []
            for l in team_since_playoffs:
                p28dT = boxscoreplayertrackv2.BoxScorePlayerTrackV2(l).get_data_frames()[0]
                if len(p28dT[p28dT['PLAYER_ID']==player_id].index.tolist())>0:
                    p28d_player = (p28dT.loc[p28dT['PLAYER_ID']==player_id]).iloc[0]['DIST']
                else:
                    p28d_player=0
                dist_past_28_days.append(p28d_player)
                time.sleep(0.6)
            twentyeight_day_average = sum(dist_past_28_days)/28
            return twentyeight_day_average
    else:
        if days_since_start<28:
            team_since_start = leaguegamefinder.LeagueGameFinder(season_nullable=szn,date_from_nullable = date_28_day_back,date_to_nullable = current_date, team_id_nullable=team_id, league_id_nullable='00', season_type_nullable=szn_type).get_data_frames()[0]['GAME_ID']
            dist_since_start = []
            for l in team_since_start:
                p28dT = boxscoreplayertrackv2.BoxScorePlayerTrackV2(l).get_data_frames()[0]
                if len(p28dT[p28dT['PLAYER_ID']==player_id].index.tolist())>0:
                    p28d_player = (p28dT.loc[p28dT['PLAYER_ID']==player_id]).iloc[0]['DIST']
                else:
                    p28d_player=0
                dist_since_start.append(p28d_player)
                time.sleep(0.6)
            avg_since_start = sum(dist_since_start)/days_since_start
            return avg_since_start
        else:
            team_past_28_days = leaguegamefinder.LeagueGameFinder(season_nullable=szn,date_from_nullable = date_28_day_back,date_to_nullable = current_date, team_id_nullable=team_id, league_id_nullable='00', season_type_nullable=szn_type).get_data_frames()[0]['GAME_ID']
            dist_over_past_28_days = []
            for l in team_past_28_days:
                p28dT = boxscoreplayertrackv2.BoxScorePlayerTrackV2(l).get_data_frames()[0]
                if len(p28dT[p28dT['PLAYER_ID']==player_id].index.tolist())>0:
                    p28d_player = (p28dT.loc[p28dT['PLAYER_ID']==player_id]).iloc[0]['DIST']
                else:
                    p28d_player=0
                dist_over_past_28_days.append(p28d_player)
                time.sleep(0.6)
            twentyeight_day_average = sum(dist_over_past_28_days)/28
            return twentyeight_day_average
rng = df.shape[0]
player_id_loc = df.columns.get_loc('player_id')
team_id_loc = df.columns.get_loc('Team_id')
teams = teams.get_teams()
team_id_dict = {}
for team in teams:
    team_id_dict[team['nickname']] = team['id']
    
#Reassigning instances here where the data either got 
#the player_ID wrong (due to instances of players sharing the same name)
#or when the data got the team name wrong

recalculate_here = sorted([9,33,1771,1345,1294,1084,916,358,133])
for i in range(rng):
    row = df.iloc[i,:]
    player_name = row['Affected Player']
    if player_name == 'Roy Marble':
        df.iat[i,player_id_loc] = 203906
        recalculate_here.append(i)
    elif player_name == 'Mike Dunleavy':
        df.iat[i,player_id_loc] = 2399
        recalculate_here.append(i)
        
recalculate_here = sorted(recalculate_here)

df.iat[9,team_id_loc] = team_id_dict['Pistons']
df.iat[33,team_id_loc] = team_id_dict['Pistons']
df.iat[133,team_id_loc] = team_id_dict['Nets']
df.iat[358,team_id_loc] = team_id_dict['Knicks']
df.iat[916,player_id_loc]=203912
df.iat[1084,team_id_loc]=team_id_dict['Bucks']
df.iat[1294,team_id_loc]=team_id_dict['Pistons']
df.iat[1345,team_id_loc]=team_id_dict['Mavericks']
df.iat[1771,team_id_loc]=team_id_dict['Grizzlies']
df['7_day_distance_avg'] = 0.123456789
df['28_day_distance_avg'] = 0.123456789
df['Acute-Chronic Workload Ratio'] = 0.123456789
SDL = df.columns.get_loc('7_day_distance_avg')
TEDL = df.columns.get_loc('28_day_distance_avg')
SDL = df.columns.get_loc('7_day_distance_avg')
TEDL = df.columns.get_loc('28_day_distance_avg')
ACWR_loc =  df.columns.get_loc('Acute-Chronic Workload Ratio')
print('done 2')



rng = df.shape[0]
print(rng)
adjusted = int(rng/2)
adjusted_range_1 = list(range(adjusted))
adjusted_range_2 = list(range(adjusted,rng))
adjusted_range_3 = list(range(499))
adjusted_range_4 = list(range(499,(499*2)))
adjusted_range_5 = list(range((499*2),(499*3)))
adjusted_range_6 = list(range((499*3),1996))
seven_days_list = [adjusted_range_1,adjusted_range_2]
lsted_list = [adjusted_range_1,adjusted_range_2,adjusted_range_3,adjusted_range_4,adjusted_range_5,adjusted_range_6]

#I used a for loop to apply these columns rather than the standard
#apply method as the nba_api blocks your IP from extracting data
#if you make too many requests without a break
#the for loop method allowed me to add a time.sleep() between every 500/1000 rows
#portion such that the api won't be overloaded with requests all the time

for lst in lsted_list:
    time.sleep(60)
    if lst in seven_days_list:
        for i in lst:
            ro = df.iloc[i,:]
            seven_day_avg = get_avg_7_days(ro)
            df.iat[i,SDL] = seven_day_avg
            printing_time = [100,200,300,400,501,600,700,800,900,1001,1100,1200,1300,1400,1501,1600,1700,1800,1990]
            if i in printing_time:
                print(i)
                if i == 501:
                    print('25% done 7 days')
                elif i == 1001:
                    print('halfway done 7 days')
                elif i == 1501:
                    print('75% done 7 days')
            checkpts = [500,1000,1500,1990]
            if i in checkpts:
                time.sleep(10)
            elif (i == adjusted_range_2[-1]):
                print('done the 7 days portion')
            else:
                continue
    else:
        for i in lst:
            ro = df.iloc[i,:]
            TE_day_avg = get_avg_28_days(ro)
            df.iat[i,TEDL] = TE_day_avg
            printing_time = [100,200,300,400,501,600,700,800,900,1001,1100,1200,1300,1400,1501,1600,1700,1800,1990]
            if i in printing_time:
                print(i)
                if i == 501:
                    print('25% done 28 days')
                elif i == 1001:
                    print('halfway done 28 days')
                elif i == 1501:
                    print('75% done 28 days')
            checkpts = [750,1250,1750]
            if i in checkpts:
                time.sleep(10)
            elif (i == lst[-1]):
                print('done this quarter 28 days')
            else:
                continue
                
for i in range(rng):
    row = df.iloc[i,:]
    seven_day_avg = row['7_day_distance_avg']
    twentyeight_day_avg = row['28_day_distance_avg']
    if twentyeight_day_avg != 0.0:
        AWCR = float(seven_day_avg/twentyeight_day_avg)
        df.iat[i,ACWR_loc] = AWCR
    else:
        AWCR = 0.0
        df.iat[i,ACWR_loc] = AWCR

#ACWR = acute/chronic workload ratio


#remove instances with an ACWR of zero 
#because they can skew the data
#people with an ACWR of 0 incurred injuries when they were NOT playing
#i.e. during practice or extracurricular activities
#and this data is not relevant to the analysis
df = df[df.iloc[:,ACWR_loc] != 0]


#deleting and rearranging the columns in order to have cleaner data
colstodrop = ['Unnamed: 0', 'Unnamed: 0.1', 'level_0', 'index', 'Unnamed: 0.1.1','Unnamed: 0.1.1.1', 'Acquired', 'Relinquished', 'Notes','Injury Type','Total','days since start', 'Season Type', 'Date_adjusted', '7_day_back', '28_day_back', 'playoff start date', 'days_since_start_of_playoffs', 'player_id', 'Team_id']
df=df_edit.drop(colstodrop,axis=1)
rearrange = ['Date', 'Team', 'Affected Player', 'Season', 'Injury Part',
       'Injury Duration','7_day_distance_avg', '28_day_distance_avg',
       'Acute-Chronic Workload Ratio', 'foot', 'knee', 'lower leg', 'upper leg', 'back',
       'arm', 'hand', 'upper body', 'core and hip', 'head and neck',
       'foot_count', 'knee_count',
       'lower leg_count', 'upper leg_count', 'back_count', 'arm_count',
       'hand_count', 'upper body_count', 'core and hip_count',
       'head and neck_count', 'Total Duration', 'Total num. of inj']

df_edit = df_edit[rearrange]

savepath= r'C:\\Users\\Dani\\Downloads'
filename = 'final_version_with_avg_distances_and_counts.csv'
filename= os.path.join(savepath,filename)
df.to_csv(filename)
print('Finished')
